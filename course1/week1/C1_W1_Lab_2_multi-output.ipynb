# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 972us/sample - loss: 256.8479 - y1_output_loss: 120.6028 - y2_output_loss: 133.8332 - y1_output_root_mean_squared_error: 11.0335 - y2_output_root_mean_squared_error: 11.6236 - val_loss: 34.8861 - val_y1_output_loss: 16.7993 - val_y2_output_loss: 18.2902 - val_y1_output_root_mean_squared_error: 4.0481 - val_y2_output_root_mean_squared_error: 4.3010
# Epoch 2/500
# 614/614 [==============================] - 0s 162us/sample - loss: 35.7871 - y1_output_loss: 13.4695 - y2_output_loss: 22.3743 - y1_output_root_mean_squared_error: 3.6404 - y2_output_root_mean_squared_error: 4.7470 - val_loss: 28.1455 - val_y1_output_loss: 12.0297 - val_y2_output_loss: 16.0572 - val_y1_output_root_mean_squared_error: 3.4281 - val_y2_output_root_mean_squared_error: 4.0489
# Epoch 3/500
# 614/614 [==============================] - 0s 130us/sample - loss: 24.2960 - y1_output_loss: 9.3528 - y2_output_loss: 14.8279 - y1_output_root_mean_squared_error: 3.0683 - y2_output_root_mean_squared_error: 3.8577 - val_loss: 22.1088 - val_y1_output_loss: 11.1526 - val_y2_output_loss: 10.8741 - val_y1_output_root_mean_squared_error: 3.3150 - val_y2_output_root_mean_squared_error: 3.3346
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 22.4994 - y1_output_loss: 9.2974 - y2_output_loss: 13.2278 - y1_output_root_mean_squared_error: 3.0365 - y2_output_root_mean_squared_error: 3.6441 - val_loss: 26.2046 - val_y1_output_loss: 12.0503 - val_y2_output_loss: 13.9211 - val_y1_output_root_mean_squared_error: 3.4463 - val_y2_output_root_mean_squared_error: 3.7852
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.5551 - y1_output_loss: 9.2758 - y2_output_loss: 15.3911 - y1_output_root_mean_squared_error: 3.0290 - y2_output_root_mean_squared_error: 3.9218 - val_loss: 29.6409 - val_y1_output_loss: 13.9127 - val_y2_output_loss: 15.4339 - val_y1_output_root_mean_squared_error: 3.7047 - val_y2_output_root_mean_squared_error: 3.9895
# Epoch 6/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.1822 - y1_output_loss: 8.3196 - y2_output_loss: 12.7513 - y1_output_root_mean_squared_error: 2.8867 - y2_output_root_mean_squared_error: 3.5846 - val_loss: 22.3487 - val_y1_output_loss: 11.1348 - val_y2_output_loss: 10.9601 - val_y1_output_root_mean_squared_error: 3.3326 - val_y2_output_root_mean_squared_error: 3.3530
# Epoch 7/500
# 614/614 [==============================] - 0s 139us/sample - loss: 23.5879 - y1_output_loss: 8.7124 - y2_output_loss: 14.8961 - y1_output_root_mean_squared_error: 2.9595 - y2_output_root_mean_squared_error: 3.8509 - val_loss: 28.2940 - val_y1_output_loss: 11.4267 - val_y2_output_loss: 16.8830 - val_y1_output_root_mean_squared_error: 3.3569 - val_y2_output_root_mean_squared_error: 4.1261
# Epoch 8/500
# 614/614 [==============================] - 0s 136us/sample - loss: 24.6070 - y1_output_loss: 8.8751 - y2_output_loss: 15.9545 - y1_output_root_mean_squared_error: 2.9640 - y2_output_root_mean_squared_error: 3.9777 - val_loss: 20.4243 - val_y1_output_loss: 9.6099 - val_y2_output_loss: 10.5399 - val_y1_output_root_mean_squared_error: 3.1060 - val_y2_output_root_mean_squared_error: 3.2829
# Epoch 9/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.2467 - y1_output_loss: 7.7124 - y2_output_loss: 11.5196 - y1_output_root_mean_squared_error: 2.7775 - y2_output_root_mean_squared_error: 3.3959 - val_loss: 44.4364 - val_y1_output_loss: 13.2184 - val_y2_output_loss: 31.6807 - val_y1_output_root_mean_squared_error: 3.6632 - val_y2_output_root_mean_squared_error: 5.5693
# Epoch 10/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.2309 - y1_output_loss: 7.8647 - y2_output_loss: 12.1736 - y1_output_root_mean_squared_error: 2.8179 - y2_output_root_mean_squared_error: 3.5057 - val_loss: 18.7828 - val_y1_output_loss: 9.2684 - val_y2_output_loss: 9.3802 - val_y1_output_root_mean_squared_error: 3.0293 - val_y2_output_root_mean_squared_error: 3.0994
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 19.4349 - y1_output_loss: 7.7267 - y2_output_loss: 11.7000 - y1_output_root_mean_squared_error: 2.7857 - y2_output_root_mean_squared_error: 3.4168 - val_loss: 22.1535 - val_y1_output_loss: 10.2573 - val_y2_output_loss: 11.6015 - val_y1_output_root_mean_squared_error: 3.2151 - val_y2_output_root_mean_squared_error: 3.4375
# Epoch 12/500
# 614/614 [==============================] - 0s 127us/sample - loss: 18.7973 - y1_output_loss: 7.3273 - y2_output_loss: 11.3302 - y1_output_root_mean_squared_error: 2.7166 - y2_output_root_mean_squared_error: 3.3790 - val_loss: 20.5464 - val_y1_output_loss: 9.9400 - val_y2_output_loss: 10.3787 - val_y1_output_root_mean_squared_error: 3.1440 - val_y2_output_root_mean_squared_error: 3.2653
# Epoch 13/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.9479 - y1_output_loss: 7.0270 - y2_output_loss: 10.8803 - y1_output_root_mean_squared_error: 2.6433 - y2_output_root_mean_squared_error: 3.3107 - val_loss: 26.8358 - val_y1_output_loss: 11.1314 - val_y2_output_loss: 15.4500 - val_y1_output_root_mean_squared_error: 3.3742 - val_y2_output_root_mean_squared_error: 3.9308
# Epoch 14/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.5527 - y1_output_loss: 6.8510 - y2_output_loss: 9.9904 - y1_output_root_mean_squared_error: 2.6010 - y2_output_root_mean_squared_error: 3.1285 - val_loss: 59.8821 - val_y1_output_loss: 19.2497 - val_y2_output_loss: 40.8808 - val_y1_output_root_mean_squared_error: 4.3242 - val_y2_output_root_mean_squared_error: 6.4174
# Epoch 15/500
# 614/614 [==============================] - 0s 126us/sample - loss: 19.3096 - y1_output_loss: 7.1146 - y2_output_loss: 12.0403 - y1_output_root_mean_squared_error: 2.6796 - y2_output_root_mean_squared_error: 3.4827 - val_loss: 17.7832 - val_y1_output_loss: 7.8658 - val_y2_output_loss: 9.8113 - val_y1_output_root_mean_squared_error: 2.8099 - val_y2_output_root_mean_squared_error: 3.1444
# Epoch 16/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.8588 - y1_output_loss: 7.0146 - y2_output_loss: 13.7374 - y1_output_root_mean_squared_error: 2.6549 - y2_output_root_mean_squared_error: 3.7162 - val_loss: 20.3013 - val_y1_output_loss: 9.9878 - val_y2_output_loss: 10.1568 - val_y1_output_root_mean_squared_error: 3.1344 - val_y2_output_root_mean_squared_error: 3.2368
# Epoch 17/500
# 614/614 [==============================] - 0s 126us/sample - loss: 17.4952 - y1_output_loss: 6.6339 - y2_output_loss: 11.1132 - y1_output_root_mean_squared_error: 2.5451 - y2_output_root_mean_squared_error: 3.3193 - val_loss: 64.8203 - val_y1_output_loss: 20.6347 - val_y2_output_loss: 44.6881 - val_y1_output_root_mean_squared_error: 4.4649 - val_y2_output_root_mean_squared_error: 6.6996
# Epoch 18/500
# 614/614 [==============================] - 0s 126us/sample - loss: 17.1506 - y1_output_loss: 6.4924 - y2_output_loss: 10.7081 - y1_output_root_mean_squared_error: 2.5340 - y2_output_root_mean_squared_error: 3.2756 - val_loss: 24.4827 - val_y1_output_loss: 11.5568 - val_y2_output_loss: 13.1086 - val_y1_output_root_mean_squared_error: 3.3323 - val_y2_output_root_mean_squared_error: 3.6577
# Epoch 19/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.0917 - y1_output_loss: 6.3483 - y2_output_loss: 10.8532 - y1_output_root_mean_squared_error: 2.5068 - y2_output_root_mean_squared_error: 3.2875 - val_loss: 45.6942 - val_y1_output_loss: 11.9722 - val_y2_output_loss: 34.4099 - val_y1_output_root_mean_squared_error: 3.4899 - val_y2_output_root_mean_squared_error: 5.7892
# Epoch 20/500
# 614/614 [==============================] - 0s 126us/sample - loss: 16.8534 - y1_output_loss: 5.9852 - y2_output_loss: 11.0207 - y1_output_root_mean_squared_error: 2.4380 - y2_output_root_mean_squared_error: 3.3030 - val_loss: 41.2941 - val_y1_output_loss: 13.5006 - val_y2_output_loss: 28.1097 - val_y1_output_root_mean_squared_error: 3.6032 - val_y2_output_root_mean_squared_error: 5.3208
# Epoch 21/500
# 614/614 [==============================] - 0s 126us/sample - loss: 15.0474 - y1_output_loss: 5.6876 - y2_output_loss: 9.3911 - y1_output_root_mean_squared_error: 2.3717 - y2_output_root_mean_squared_error: 3.0696 - val_loss: 15.4423 - val_y1_output_loss: 7.9527 - val_y2_output_loss: 7.4824 - val_y1_output_root_mean_squared_error: 2.7767 - val_y2_output_root_mean_squared_error: 2.7807
# Epoch 22/500
# 614/614 [==============================] - 0s 125us/sample - loss: 15.8383 - y1_output_loss: 5.6609 - y2_output_loss: 10.2368 - y1_output_root_mean_squared_error: 2.3787 - y2_output_root_mean_squared_error: 3.1906 - val_loss: 14.6993 - val_y1_output_loss: 6.0325 - val_y2_output_loss: 8.3117 - val_y1_output_root_mean_squared_error: 2.4686 - val_y2_output_root_mean_squared_error: 2.9335
# Epoch 23/500
# 614/614 [==============================] - 0s 127us/sample - loss: 15.0033 - y1_output_loss: 5.2687 - y2_output_loss: 9.6004 - y1_output_root_mean_squared_error: 2.3051 - y2_output_root_mean_squared_error: 3.1129 - val_loss: 12.8151 - val_y1_output_loss: 6.0348 - val_y2_output_loss: 6.5820 - val_y1_output_root_mean_squared_error: 2.4685 - val_y2_output_root_mean_squared_error: 2.5926
# Epoch 24/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.3556 - y1_output_loss: 4.8019 - y2_output_loss: 7.5488 - y1_output_root_mean_squared_error: 2.1931 - y2_output_root_mean_squared_error: 2.7470 - val_loss: 11.7977 - val_y1_output_loss: 5.6690 - val_y2_output_loss: 5.9576 - val_y1_output_root_mean_squared_error: 2.3748 - val_y2_output_root_mean_squared_error: 2.4816
# Epoch 25/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.4106 - y1_output_loss: 4.8321 - y2_output_loss: 7.6759 - y1_output_root_mean_squared_error: 2.1816 - y2_output_root_mean_squared_error: 2.7661 - val_loss: 30.9271 - val_y1_output_loss: 8.5023 - val_y2_output_loss: 22.5569 - val_y1_output_root_mean_squared_error: 2.8562 - val_y2_output_root_mean_squared_error: 4.7717
# Epoch 26/500
# 614/614 [==============================] - 0s 126us/sample - loss: 12.4286 - y1_output_loss: 4.6365 - y2_output_loss: 7.9176 - y1_output_root_mean_squared_error: 2.1531 - y2_output_root_mean_squared_error: 2.7916 - val_loss: 42.3388 - val_y1_output_loss: 9.9905 - val_y2_output_loss: 32.1772 - val_y1_output_root_mean_squared_error: 3.2102 - val_y2_output_root_mean_squared_error: 5.6598
# Epoch 27/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.9643 - y1_output_loss: 4.6789 - y2_output_loss: 8.2389 - y1_output_root_mean_squared_error: 2.1607 - y2_output_root_mean_squared_error: 2.8802 - val_loss: 16.3337 - val_y1_output_loss: 6.6493 - val_y2_output_loss: 9.7845 - val_y1_output_root_mean_squared_error: 2.5910 - val_y2_output_root_mean_squared_error: 3.1017
# Epoch 28/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.0017 - y1_output_loss: 4.6688 - y2_output_loss: 8.2613 - y1_output_root_mean_squared_error: 2.1704 - y2_output_root_mean_squared_error: 2.8794 - val_loss: 11.1128 - val_y1_output_loss: 5.0756 - val_y2_output_loss: 5.9438 - val_y1_output_root_mean_squared_error: 2.2434 - val_y2_output_root_mean_squared_error: 2.4657
# Epoch 29/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.2302 - y1_output_loss: 3.8798 - y2_output_loss: 6.4547 - y1_output_root_mean_squared_error: 1.9698 - y2_output_root_mean_squared_error: 2.5200 - val_loss: 16.3077 - val_y1_output_loss: 5.7893 - val_y2_output_loss: 10.4493 - val_y1_output_root_mean_squared_error: 2.4397 - val_y2_output_root_mean_squared_error: 3.2180
# Epoch 30/500
# 614/614 [==============================] - 0s 134us/sample - loss: 11.1731 - y1_output_loss: 4.0383 - y2_output_loss: 7.0684 - y1_output_root_mean_squared_error: 2.0165 - y2_output_root_mean_squared_error: 2.6658 - val_loss: 9.7923 - val_y1_output_loss: 4.3614 - val_y2_output_loss: 5.3095 - val_y1_output_root_mean_squared_error: 2.0950 - val_y2_output_root_mean_squared_error: 2.3245
# Epoch 31/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.2270 - y1_output_loss: 3.7890 - y2_output_loss: 6.4457 - y1_output_root_mean_squared_error: 1.9439 - y2_output_root_mean_squared_error: 2.5393 - val_loss: 12.4367 - val_y1_output_loss: 5.0412 - val_y2_output_loss: 7.2512 - val_y1_output_root_mean_squared_error: 2.2707 - val_y2_output_root_mean_squared_error: 2.6982
# Epoch 32/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.5335 - y1_output_loss: 4.0791 - y2_output_loss: 8.3410 - y1_output_root_mean_squared_error: 2.0287 - y2_output_root_mean_squared_error: 2.9014 - val_loss: 13.5136 - val_y1_output_loss: 4.5119 - val_y2_output_loss: 9.1397 - val_y1_output_root_mean_squared_error: 2.1525 - val_y2_output_root_mean_squared_error: 2.9800
# Epoch 33/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.3982 - y1_output_loss: 3.9480 - y2_output_loss: 7.5340 - y1_output_root_mean_squared_error: 1.9581 - y2_output_root_mean_squared_error: 2.7503 - val_loss: 34.0444 - val_y1_output_loss: 15.5598 - val_y2_output_loss: 17.9804 - val_y1_output_root_mean_squared_error: 3.9311 - val_y2_output_root_mean_squared_error: 4.3117
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.6322 - y1_output_loss: 3.6195 - y2_output_loss: 6.0380 - y1_output_root_mean_squared_error: 1.9021 - y2_output_root_mean_squared_error: 2.4524 - val_loss: 10.3758 - val_y1_output_loss: 3.8219 - val_y2_output_loss: 6.6712 - val_y1_output_root_mean_squared_error: 1.9599 - val_y2_output_root_mean_squared_error: 2.5563
# Epoch 35/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.1361 - y1_output_loss: 3.2813 - y2_output_loss: 5.8925 - y1_output_root_mean_squared_error: 1.7950 - y2_output_root_mean_squared_error: 2.4319 - val_loss: 10.2705 - val_y1_output_loss: 4.6496 - val_y2_output_loss: 5.4659 - val_y1_output_root_mean_squared_error: 2.1472 - val_y2_output_root_mean_squared_error: 2.3791
# Epoch 36/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.8828 - y1_output_loss: 3.8057 - y2_output_loss: 7.0184 - y1_output_root_mean_squared_error: 1.9520 - y2_output_root_mean_squared_error: 2.6594 - val_loss: 10.7752 - val_y1_output_loss: 4.7563 - val_y2_output_loss: 5.9102 - val_y1_output_root_mean_squared_error: 2.1535 - val_y2_output_root_mean_squared_error: 2.4774
# Epoch 37/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.8063 - y1_output_loss: 3.4037 - y2_output_loss: 7.3762 - y1_output_root_mean_squared_error: 1.8416 - y2_output_root_mean_squared_error: 2.7230 - val_loss: 13.5932 - val_y1_output_loss: 5.0808 - val_y2_output_loss: 8.5801 - val_y1_output_root_mean_squared_error: 2.2878 - val_y2_output_root_mean_squared_error: 2.8912
# Epoch 38/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.5586 - y1_output_loss: 2.7128 - y2_output_loss: 5.8691 - y1_output_root_mean_squared_error: 1.6468 - y2_output_root_mean_squared_error: 2.4180 - val_loss: 7.7790 - val_y1_output_loss: 3.6651 - val_y2_output_loss: 4.1034 - val_y1_output_root_mean_squared_error: 1.9000 - val_y2_output_root_mean_squared_error: 2.0418
# Epoch 39/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0256 - y1_output_loss: 2.4481 - y2_output_loss: 4.6265 - y1_output_root_mean_squared_error: 1.5665 - y2_output_root_mean_squared_error: 2.1382 - val_loss: 28.9648 - val_y1_output_loss: 5.8236 - val_y2_output_loss: 23.9909 - val_y1_output_root_mean_squared_error: 2.4402 - val_y2_output_root_mean_squared_error: 4.7969
# Epoch 40/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.2128 - y1_output_loss: 3.1657 - y2_output_loss: 6.0249 - y1_output_root_mean_squared_error: 1.7866 - y2_output_root_mean_squared_error: 2.4538 - val_loss: 17.1066 - val_y1_output_loss: 4.6288 - val_y2_output_loss: 12.6402 - val_y1_output_root_mean_squared_error: 2.1902 - val_y2_output_root_mean_squared_error: 3.5085
# Epoch 41/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.4670 - y1_output_loss: 2.6931 - y2_output_loss: 5.7982 - y1_output_root_mean_squared_error: 1.6275 - y2_output_root_mean_squared_error: 2.4121 - val_loss: 19.8624 - val_y1_output_loss: 5.6900 - val_y2_output_loss: 14.2878 - val_y1_output_root_mean_squared_error: 2.4256 - val_y2_output_root_mean_squared_error: 3.7388
# Epoch 42/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.1856 - y1_output_loss: 2.3888 - y2_output_loss: 4.8719 - y1_output_root_mean_squared_error: 1.5385 - y2_output_root_mean_squared_error: 2.1951 - val_loss: 17.8286 - val_y1_output_loss: 3.4769 - val_y2_output_loss: 14.5104 - val_y1_output_root_mean_squared_error: 1.8830 - val_y2_output_root_mean_squared_error: 3.7793
# Epoch 43/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.0454 - y1_output_loss: 2.3899 - y2_output_loss: 4.7447 - y1_output_root_mean_squared_error: 1.5465 - y2_output_root_mean_squared_error: 2.1573 - val_loss: 62.6950 - val_y1_output_loss: 8.4099 - val_y2_output_loss: 55.1465 - val_y1_output_root_mean_squared_error: 2.9469 - val_y2_output_root_mean_squared_error: 7.3492
# Epoch 44/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.3875 - y1_output_loss: 2.9232 - y2_output_loss: 6.4857 - y1_output_root_mean_squared_error: 1.7154 - y2_output_root_mean_squared_error: 2.5387 - val_loss: 8.7458 - val_y1_output_loss: 3.1601 - val_y2_output_loss: 5.6394 - val_y1_output_root_mean_squared_error: 1.8062 - val_y2_output_root_mean_squared_error: 2.3416
# Epoch 45/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.8256 - y1_output_loss: 2.2633 - y2_output_loss: 4.5125 - y1_output_root_mean_squared_error: 1.5089 - y2_output_root_mean_squared_error: 2.1328 - val_loss: 7.3904 - val_y1_output_loss: 2.8849 - val_y2_output_loss: 4.4267 - val_y1_output_root_mean_squared_error: 1.7106 - val_y2_output_root_mean_squared_error: 2.1129
# Epoch 46/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.8135 - y1_output_loss: 1.9299 - y2_output_loss: 3.8615 - y1_output_root_mean_squared_error: 1.3916 - y2_output_root_mean_squared_error: 1.9690 - val_loss: 7.0332 - val_y1_output_loss: 3.0585 - val_y2_output_loss: 3.9108 - val_y1_output_root_mean_squared_error: 1.7739 - val_y2_output_root_mean_squared_error: 1.9714
# Epoch 47/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.6020 - y1_output_loss: 2.0901 - y2_output_loss: 4.5239 - y1_output_root_mean_squared_error: 1.4476 - y2_output_root_mean_squared_error: 2.1228 - val_loss: 12.1104 - val_y1_output_loss: 3.2363 - val_y2_output_loss: 9.2023 - val_y1_output_root_mean_squared_error: 1.8243 - val_y2_output_root_mean_squared_error: 2.9635
# Epoch 48/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.6563 - y1_output_loss: 2.2301 - y2_output_loss: 4.4360 - y1_output_root_mean_squared_error: 1.4914 - y2_output_root_mean_squared_error: 2.1052 - val_loss: 7.8211 - val_y1_output_loss: 2.5454 - val_y2_output_loss: 5.5095 - val_y1_output_root_mean_squared_error: 1.6178 - val_y2_output_root_mean_squared_error: 2.2812
# Epoch 49/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.0895 - y1_output_loss: 2.2749 - y2_output_loss: 4.8942 - y1_output_root_mean_squared_error: 1.5045 - y2_output_root_mean_squared_error: 2.1968 - val_loss: 16.0072 - val_y1_output_loss: 4.4889 - val_y2_output_loss: 11.3857 - val_y1_output_root_mean_squared_error: 2.0871 - val_y2_output_root_mean_squared_error: 3.4134
# Epoch 50/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.7484 - y1_output_loss: 2.0950 - y2_output_loss: 4.5960 - y1_output_root_mean_squared_error: 1.4531 - y2_output_root_mean_squared_error: 2.1533 - val_loss: 9.8622 - val_y1_output_loss: 3.4927 - val_y2_output_loss: 6.5024 - val_y1_output_root_mean_squared_error: 1.9004 - val_y2_output_root_mean_squared_error: 2.5001
# Epoch 51/500
# 614/614 [==============================] - 0s 123us/sample - loss: 15.0104 - y1_output_loss: 4.4922 - y2_output_loss: 10.4512 - y1_output_root_mean_squared_error: 2.1252 - y2_output_root_mean_squared_error: 3.2394 - val_loss: 11.4935 - val_y1_output_loss: 3.2749 - val_y2_output_loss: 8.5136 - val_y1_output_root_mean_squared_error: 1.8414 - val_y2_output_root_mean_squared_error: 2.8465
# Epoch 52/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.1132 - y1_output_loss: 1.8883 - y2_output_loss: 4.4495 - y1_output_root_mean_squared_error: 1.3676 - y2_output_root_mean_squared_error: 2.0598 - val_loss: 66.5348 - val_y1_output_loss: 15.0272 - val_y2_output_loss: 52.3462 - val_y1_output_root_mean_squared_error: 3.9222 - val_y2_output_root_mean_squared_error: 7.1520
# Epoch 53/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.6647 - y1_output_loss: 2.4476 - y2_output_loss: 5.1753 - y1_output_root_mean_squared_error: 1.5645 - y2_output_root_mean_squared_error: 2.2841 - val_loss: 5.7141 - val_y1_output_loss: 2.0260 - val_y2_output_loss: 3.5555 - val_y1_output_root_mean_squared_error: 1.4388 - val_y2_output_root_mean_squared_error: 1.9089
# Epoch 54/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.5554 - y1_output_loss: 1.7257 - y2_output_loss: 3.7962 - y1_output_root_mean_squared_error: 1.3176 - y2_output_root_mean_squared_error: 1.9543 - val_loss: 5.7886 - val_y1_output_loss: 1.9124 - val_y2_output_loss: 3.7803 - val_y1_output_root_mean_squared_error: 1.3876 - val_y2_output_root_mean_squared_error: 1.9655
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.2710 - y1_output_loss: 1.6560 - y2_output_loss: 3.6425 - y1_output_root_mean_squared_error: 1.2845 - y2_output_root_mean_squared_error: 1.9029 - val_loss: 12.2384 - val_y1_output_loss: 4.5187 - val_y2_output_loss: 7.4226 - val_y1_output_root_mean_squared_error: 2.1377 - val_y2_output_root_mean_squared_error: 2.7692
# Epoch 56/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4908 - y1_output_loss: 1.4756 - y2_output_loss: 3.0072 - y1_output_root_mean_squared_error: 1.2204 - y2_output_root_mean_squared_error: 1.7324 - val_loss: 12.7441 - val_y1_output_loss: 2.3339 - val_y2_output_loss: 11.1399 - val_y1_output_root_mean_squared_error: 1.5502 - val_y2_output_root_mean_squared_error: 3.2157
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.6430 - y1_output_loss: 1.5155 - y2_output_loss: 3.0958 - y1_output_root_mean_squared_error: 1.2356 - y2_output_root_mean_squared_error: 1.7653 - val_loss: 5.2218 - val_y1_output_loss: 1.6539 - val_y2_output_loss: 3.7139 - val_y1_output_root_mean_squared_error: 1.2995 - val_y2_output_root_mean_squared_error: 1.8796
# Epoch 58/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.1150 - y1_output_loss: 1.6162 - y2_output_loss: 3.4870 - y1_output_root_mean_squared_error: 1.2678 - y2_output_root_mean_squared_error: 1.8729 - val_loss: 7.9258 - val_y1_output_loss: 1.8464 - val_y2_output_loss: 6.3767 - val_y1_output_root_mean_squared_error: 1.3749 - val_y2_output_root_mean_squared_error: 2.4567
# Epoch 59/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.5650 - y1_output_loss: 1.8040 - y2_output_loss: 4.7665 - y1_output_root_mean_squared_error: 1.3467 - y2_output_root_mean_squared_error: 2.1797 - val_loss: 4.9990 - val_y1_output_loss: 1.9002 - val_y2_output_loss: 3.0992 - val_y1_output_root_mean_squared_error: 1.3785 - val_y2_output_root_mean_squared_error: 1.7603
# Epoch 60/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.4771 - y1_output_loss: 1.3565 - y2_output_loss: 3.1027 - y1_output_root_mean_squared_error: 1.1672 - y2_output_root_mean_squared_error: 1.7649 - val_loss: 8.3695 - val_y1_output_loss: 1.9506 - val_y2_output_loss: 6.1793 - val_y1_output_root_mean_squared_error: 1.4032 - val_y2_output_root_mean_squared_error: 2.5299
# Epoch 61/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.2097 - y1_output_loss: 1.4779 - y2_output_loss: 3.7135 - y1_output_root_mean_squared_error: 1.2194 - y2_output_root_mean_squared_error: 1.9295 - val_loss: 5.1754 - val_y1_output_loss: 1.3974 - val_y2_output_loss: 4.0693 - val_y1_output_root_mean_squared_error: 1.1984 - val_y2_output_root_mean_squared_error: 1.9337
# Epoch 62/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0971 - y1_output_loss: 1.2253 - y2_output_loss: 2.8642 - y1_output_root_mean_squared_error: 1.1110 - y2_output_root_mean_squared_error: 1.6920 - val_loss: 4.8492 - val_y1_output_loss: 1.5398 - val_y2_output_loss: 3.4758 - val_y1_output_root_mean_squared_error: 1.2573 - val_y2_output_root_mean_squared_error: 1.8079
# Epoch 63/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8013 - y1_output_loss: 1.4158 - y2_output_loss: 3.4324 - y1_output_root_mean_squared_error: 1.1931 - y2_output_root_mean_squared_error: 1.8379 - val_loss: 58.2940 - val_y1_output_loss: 8.2164 - val_y2_output_loss: 51.7373 - val_y1_output_root_mean_squared_error: 2.8945 - val_y2_output_root_mean_squared_error: 7.0651
# Epoch 64/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6016 - y1_output_loss: 1.6899 - y2_output_loss: 3.9088 - y1_output_root_mean_squared_error: 1.3008 - y2_output_root_mean_squared_error: 1.9773 - val_loss: 5.5757 - val_y1_output_loss: 1.9164 - val_y2_output_loss: 3.8567 - val_y1_output_root_mean_squared_error: 1.3999 - val_y2_output_root_mean_squared_error: 1.9016
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.4222 - y1_output_loss: 1.9552 - y2_output_loss: 4.4199 - y1_output_root_mean_squared_error: 1.4042 - y2_output_root_mean_squared_error: 2.1096 - val_loss: 11.4663 - val_y1_output_loss: 3.9167 - val_y2_output_loss: 7.8485 - val_y1_output_root_mean_squared_error: 2.0102 - val_y2_output_root_mean_squared_error: 2.7250
# Epoch 66/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.3068 - y1_output_loss: 1.6786 - y2_output_loss: 4.6189 - y1_output_root_mean_squared_error: 1.2971 - y2_output_root_mean_squared_error: 2.1504 - val_loss: 5.8663 - val_y1_output_loss: 1.5428 - val_y2_output_loss: 4.5411 - val_y1_output_root_mean_squared_error: 1.2622 - val_y2_output_root_mean_squared_error: 2.0672
# Epoch 67/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0946 - y1_output_loss: 1.2243 - y2_output_loss: 2.8794 - y1_output_root_mean_squared_error: 1.1038 - y2_output_root_mean_squared_error: 1.6960 - val_loss: 9.5339 - val_y1_output_loss: 2.3442 - val_y2_output_loss: 7.0051 - val_y1_output_root_mean_squared_error: 1.5146 - val_y2_output_root_mean_squared_error: 2.6907
# Epoch 68/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.4386 - y1_output_loss: 1.6452 - y2_output_loss: 3.7635 - y1_output_root_mean_squared_error: 1.2806 - y2_output_root_mean_squared_error: 1.9490 - val_loss: 6.4932 - val_y1_output_loss: 2.5087 - val_y2_output_loss: 4.1017 - val_y1_output_root_mean_squared_error: 1.6065 - val_y2_output_root_mean_squared_error: 1.9780
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.8429 - y1_output_loss: 1.4694 - y2_output_loss: 3.3489 - y1_output_root_mean_squared_error: 1.2151 - y2_output_root_mean_squared_error: 1.8348 - val_loss: 5.0325 - val_y1_output_loss: 1.3892 - val_y2_output_loss: 3.8525 - val_y1_output_root_mean_squared_error: 1.1969 - val_y2_output_root_mean_squared_error: 1.8973
# Epoch 70/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1623 - y1_output_loss: 1.2167 - y2_output_loss: 2.9351 - y1_output_root_mean_squared_error: 1.1002 - y2_output_root_mean_squared_error: 1.7181 - val_loss: 4.8302 - val_y1_output_loss: 1.6975 - val_y2_output_loss: 3.1018 - val_y1_output_root_mean_squared_error: 1.2948 - val_y2_output_root_mean_squared_error: 1.7758
# Epoch 71/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8668 - y1_output_loss: 1.0491 - y2_output_loss: 2.8201 - y1_output_root_mean_squared_error: 1.0281 - y2_output_root_mean_squared_error: 1.6763 - val_loss: 3.7982 - val_y1_output_loss: 1.2032 - val_y2_output_loss: 2.6603 - val_y1_output_root_mean_squared_error: 1.1094 - val_y2_output_root_mean_squared_error: 1.6024
# Epoch 72/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.4553 - y1_output_loss: 0.9876 - y2_output_loss: 2.4636 - y1_output_root_mean_squared_error: 0.9939 - y2_output_root_mean_squared_error: 1.5708 - val_loss: 5.1976 - val_y1_output_loss: 1.2070 - val_y2_output_loss: 4.3518 - val_y1_output_root_mean_squared_error: 1.1100 - val_y2_output_root_mean_squared_error: 1.9913
# Epoch 73/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0062 - y1_output_loss: 0.8482 - y2_output_loss: 2.1810 - y1_output_root_mean_squared_error: 0.9178 - y2_output_root_mean_squared_error: 1.4710 - val_loss: 4.5344 - val_y1_output_loss: 1.0956 - val_y2_output_loss: 3.3684 - val_y1_output_root_mean_squared_error: 1.0541 - val_y2_output_root_mean_squared_error: 1.8502
# Epoch 74/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.4683 - y1_output_loss: 1.0223 - y2_output_loss: 2.4824 - y1_output_root_mean_squared_error: 1.0115 - y2_output_root_mean_squared_error: 1.5637 - val_loss: 5.9457 - val_y1_output_loss: 1.5141 - val_y2_output_loss: 4.8885 - val_y1_output_root_mean_squared_error: 1.2419 - val_y2_output_root_mean_squared_error: 2.0984
# Epoch 75/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4036 - y1_output_loss: 0.9453 - y2_output_loss: 2.4852 - y1_output_root_mean_squared_error: 0.9735 - y2_output_root_mean_squared_error: 1.5671 - val_loss: 11.5774 - val_y1_output_loss: 1.7193 - val_y2_output_loss: 10.4791 - val_y1_output_root_mean_squared_error: 1.3334 - val_y2_output_root_mean_squared_error: 3.1304
# Epoch 76/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.0011 - y1_output_loss: 1.0787 - y2_output_loss: 2.8961 - y1_output_root_mean_squared_error: 1.0423 - y2_output_root_mean_squared_error: 1.7073 - val_loss: 4.2534 - val_y1_output_loss: 1.0154 - val_y2_output_loss: 3.5122 - val_y1_output_root_mean_squared_error: 1.0205 - val_y2_output_root_mean_squared_error: 1.7922
# Epoch 77/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.8458 - y1_output_loss: 1.0371 - y2_output_loss: 2.7779 - y1_output_root_mean_squared_error: 1.0214 - y2_output_root_mean_squared_error: 1.6741 - val_loss: 5.1644 - val_y1_output_loss: 1.3639 - val_y2_output_loss: 4.1678 - val_y1_output_root_mean_squared_error: 1.1847 - val_y2_output_root_mean_squared_error: 1.9393
# Epoch 78/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.4835 - y1_output_loss: 1.0378 - y2_output_loss: 2.4227 - y1_output_root_mean_squared_error: 1.0215 - y2_output_root_mean_squared_error: 1.5621 - val_loss: 4.5204 - val_y1_output_loss: 0.9100 - val_y2_output_loss: 3.9473 - val_y1_output_root_mean_squared_error: 0.9694 - val_y2_output_root_mean_squared_error: 1.8923
# Epoch 79/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8085 - y1_output_loss: 0.9907 - y2_output_loss: 2.7958 - y1_output_root_mean_squared_error: 0.9941 - y2_output_root_mean_squared_error: 1.6794 - val_loss: 3.7195 - val_y1_output_loss: 0.9965 - val_y2_output_loss: 2.8582 - val_y1_output_root_mean_squared_error: 1.0116 - val_y2_output_root_mean_squared_error: 1.6420
# Epoch 80/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.4776 - y1_output_loss: 1.3321 - y2_output_loss: 3.1074 - y1_output_root_mean_squared_error: 1.1590 - y2_output_root_mean_squared_error: 1.7704 - val_loss: 3.6142 - val_y1_output_loss: 1.0162 - val_y2_output_loss: 2.7010 - val_y1_output_root_mean_squared_error: 1.0131 - val_y2_output_root_mean_squared_error: 1.6087
# Epoch 81/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.4443 - y1_output_loss: 1.0154 - y2_output_loss: 2.4050 - y1_output_root_mean_squared_error: 1.0119 - y2_output_root_mean_squared_error: 1.5557 - val_loss: 5.4583 - val_y1_output_loss: 1.2328 - val_y2_output_loss: 4.6758 - val_y1_output_root_mean_squared_error: 1.1260 - val_y2_output_root_mean_squared_error: 2.0470
# Epoch 82/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9295 - y1_output_loss: 0.8602 - y2_output_loss: 2.1700 - y1_output_root_mean_squared_error: 0.9254 - y2_output_root_mean_squared_error: 1.4399 - val_loss: 18.4584 - val_y1_output_loss: 4.3488 - val_y2_output_loss: 13.6438 - val_y1_output_root_mean_squared_error: 2.0883 - val_y2_output_root_mean_squared_error: 3.7546
# Epoch 83/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0370 - y1_output_loss: 0.8622 - y2_output_loss: 2.1686 - y1_output_root_mean_squared_error: 0.9308 - y2_output_root_mean_squared_error: 1.4733 - val_loss: 3.8601 - val_y1_output_loss: 0.9685 - val_y2_output_loss: 2.9711 - val_y1_output_root_mean_squared_error: 0.9984 - val_y2_output_root_mean_squared_error: 1.6921
# Epoch 84/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.1610 - y1_output_loss: 0.9135 - y2_output_loss: 2.2279 - y1_output_root_mean_squared_error: 0.9576 - y2_output_root_mean_squared_error: 1.4980 - val_loss: 4.3185 - val_y1_output_loss: 0.9850 - val_y2_output_loss: 3.3053 - val_y1_output_root_mean_squared_error: 1.0023 - val_y2_output_root_mean_squared_error: 1.8204
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6673 - y1_output_loss: 0.6617 - y2_output_loss: 2.0241 - y1_output_root_mean_squared_error: 0.8128 - y2_output_root_mean_squared_error: 1.4166 - val_loss: 8.2553 - val_y1_output_loss: 1.2918 - val_y2_output_loss: 6.7165 - val_y1_output_root_mean_squared_error: 1.1448 - val_y2_output_root_mean_squared_error: 2.6353
# Epoch 86/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.8487 - y1_output_loss: 2.0410 - y2_output_loss: 4.7780 - y1_output_root_mean_squared_error: 1.4336 - y2_output_root_mean_squared_error: 2.1894 - val_loss: 9.0826 - val_y1_output_loss: 2.4103 - val_y2_output_loss: 6.5105 - val_y1_output_root_mean_squared_error: 1.5712 - val_y2_output_root_mean_squared_error: 2.5718
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1366 - y1_output_loss: 0.9642 - y2_output_loss: 2.1903 - y1_output_root_mean_squared_error: 0.9796 - y2_output_root_mean_squared_error: 1.4754 - val_loss: 4.7811 - val_y1_output_loss: 1.5099 - val_y2_output_loss: 3.5817 - val_y1_output_root_mean_squared_error: 1.2431 - val_y2_output_root_mean_squared_error: 1.7988
# Epoch 88/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5250 - y1_output_loss: 0.7546 - y2_output_loss: 1.7651 - y1_output_root_mean_squared_error: 0.8682 - y2_output_root_mean_squared_error: 1.3309 - val_loss: 3.7273 - val_y1_output_loss: 0.7382 - val_y2_output_loss: 3.4094 - val_y1_output_root_mean_squared_error: 0.8681 - val_y2_output_root_mean_squared_error: 1.7245
# Epoch 89/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.7284 - y1_output_loss: 2.1021 - y2_output_loss: 4.5971 - y1_output_root_mean_squared_error: 1.4560 - y2_output_root_mean_squared_error: 2.1468 - val_loss: 4.7705 - val_y1_output_loss: 1.2839 - val_y2_output_loss: 3.7350 - val_y1_output_root_mean_squared_error: 1.1449 - val_y2_output_root_mean_squared_error: 1.8601
# Epoch 90/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4688 - y1_output_loss: 0.6516 - y2_output_loss: 1.7974 - y1_output_root_mean_squared_error: 0.8108 - y2_output_root_mean_squared_error: 1.3459 - val_loss: 3.3576 - val_y1_output_loss: 0.8987 - val_y2_output_loss: 2.5593 - val_y1_output_root_mean_squared_error: 0.9580 - val_y2_output_root_mean_squared_error: 1.5620
# Epoch 91/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9958 - y1_output_loss: 0.7699 - y2_output_loss: 2.2338 - y1_output_root_mean_squared_error: 0.8713 - y2_output_root_mean_squared_error: 1.4956 - val_loss: 3.3285 - val_y1_output_loss: 1.0455 - val_y2_output_loss: 2.4626 - val_y1_output_root_mean_squared_error: 1.0357 - val_y2_output_root_mean_squared_error: 1.5019
# Epoch 92/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.0770 - y1_output_loss: 0.7608 - y2_output_loss: 2.3101 - y1_output_root_mean_squared_error: 0.8762 - y2_output_root_mean_squared_error: 1.5196 - val_loss: 4.0844 - val_y1_output_loss: 0.8572 - val_y2_output_loss: 3.5143 - val_y1_output_root_mean_squared_error: 0.9399 - val_y2_output_root_mean_squared_error: 1.7892
# Epoch 93/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.0622 - y1_output_loss: 0.7845 - y2_output_loss: 2.2564 - y1_output_root_mean_squared_error: 0.8872 - y2_output_root_mean_squared_error: 1.5083 - val_loss: 4.0246 - val_y1_output_loss: 0.6310 - val_y2_output_loss: 3.7086 - val_y1_output_root_mean_squared_error: 0.8006 - val_y2_output_root_mean_squared_error: 1.8395
# Epoch 94/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4912 - y1_output_loss: 0.6576 - y2_output_loss: 1.8372 - y1_output_root_mean_squared_error: 0.8104 - y2_output_root_mean_squared_error: 1.3545 - val_loss: 5.3830 - val_y1_output_loss: 0.9401 - val_y2_output_loss: 5.0067 - val_y1_output_root_mean_squared_error: 0.9818 - val_y2_output_root_mean_squared_error: 2.1022
# Epoch 95/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3470 - y1_output_loss: 0.6621 - y2_output_loss: 1.7104 - y1_output_root_mean_squared_error: 0.8118 - y2_output_root_mean_squared_error: 1.2992 - val_loss: 7.7222 - val_y1_output_loss: 2.1362 - val_y2_output_loss: 5.4309 - val_y1_output_root_mean_squared_error: 1.4577 - val_y2_output_root_mean_squared_error: 2.3659
# Epoch 96/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.2823 - y1_output_loss: 1.4274 - y2_output_loss: 2.8480 - y1_output_root_mean_squared_error: 1.1992 - y2_output_root_mean_squared_error: 1.6865 - val_loss: 5.3426 - val_y1_output_loss: 0.6049 - val_y2_output_loss: 5.2895 - val_y1_output_root_mean_squared_error: 0.7815 - val_y2_output_root_mean_squared_error: 2.1753
# Epoch 97/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3764 - y1_output_loss: 0.9254 - y2_output_loss: 2.4522 - y1_output_root_mean_squared_error: 0.9619 - y2_output_root_mean_squared_error: 1.5656 - val_loss: 3.5654 - val_y1_output_loss: 1.1396 - val_y2_output_loss: 2.5494 - val_y1_output_root_mean_squared_error: 1.0871 - val_y2_output_root_mean_squared_error: 1.5439
# Epoch 98/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9791 - y1_output_loss: 0.6876 - y2_output_loss: 2.2670 - y1_output_root_mean_squared_error: 0.8323 - y2_output_root_mean_squared_error: 1.5121 - val_loss: 2.7875 - val_y1_output_loss: 0.5739 - val_y2_output_loss: 2.4345 - val_y1_output_root_mean_squared_error: 0.7696 - val_y2_output_root_mean_squared_error: 1.4816
# Epoch 99/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.2918 - y1_output_loss: 0.6687 - y2_output_loss: 1.6498 - y1_output_root_mean_squared_error: 0.8172 - y2_output_root_mean_squared_error: 1.2743 - val_loss: 7.1872 - val_y1_output_loss: 1.4492 - val_y2_output_loss: 5.5583 - val_y1_output_root_mean_squared_error: 1.1923 - val_y2_output_root_mean_squared_error: 2.4012
# Epoch 100/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.3583 - y1_output_loss: 1.3624 - y2_output_loss: 2.9792 - y1_output_root_mean_squared_error: 1.1728 - y2_output_root_mean_squared_error: 1.7271 - val_loss: 10.1090 - val_y1_output_loss: 3.1656 - val_y2_output_loss: 6.6692 - val_y1_output_root_mean_squared_error: 1.7939 - val_y2_output_root_mean_squared_error: 2.6251
# Epoch 101/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1793 - y1_output_loss: 0.9488 - y2_output_loss: 2.2144 - y1_output_root_mean_squared_error: 0.9730 - y2_output_root_mean_squared_error: 1.4942 - val_loss: 4.5242 - val_y1_output_loss: 0.7991 - val_y2_output_loss: 4.1771 - val_y1_output_root_mean_squared_error: 0.9054 - val_y2_output_root_mean_squared_error: 1.9247
# Epoch 102/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3074 - y1_output_loss: 0.7303 - y2_output_loss: 2.6149 - y1_output_root_mean_squared_error: 0.8523 - y2_output_root_mean_squared_error: 1.6065 - val_loss: 10.4003 - val_y1_output_loss: 1.5773 - val_y2_output_loss: 8.4944 - val_y1_output_root_mean_squared_error: 1.2638 - val_y2_output_root_mean_squared_error: 2.9670
# Epoch 103/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8492 - y1_output_loss: 0.6828 - y2_output_loss: 2.1630 - y1_output_root_mean_squared_error: 0.8292 - y2_output_root_mean_squared_error: 1.4702 - val_loss: 8.4862 - val_y1_output_loss: 0.6044 - val_y2_output_loss: 8.5754 - val_y1_output_root_mean_squared_error: 0.7871 - val_y2_output_root_mean_squared_error: 2.8048
# Epoch 104/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3247 - y1_output_loss: 0.8226 - y2_output_loss: 2.5007 - y1_output_root_mean_squared_error: 0.9069 - y2_output_root_mean_squared_error: 1.5818 - val_loss: 4.8205 - val_y1_output_loss: 1.4944 - val_y2_output_loss: 3.3616 - val_y1_output_root_mean_squared_error: 1.2360 - val_y2_output_root_mean_squared_error: 1.8146
# Epoch 105/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.2950 - y1_output_loss: 0.6167 - y2_output_loss: 1.6624 - y1_output_root_mean_squared_error: 0.7883 - y2_output_root_mean_squared_error: 1.2937 - val_loss: 2.8385 - val_y1_output_loss: 0.5643 - val_y2_output_loss: 2.4978 - val_y1_output_root_mean_squared_error: 0.7610 - val_y2_output_root_mean_squared_error: 1.5031
# Epoch 106/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.2211 - y1_output_loss: 0.5315 - y2_output_loss: 1.6738 - y1_output_root_mean_squared_error: 0.7313 - y2_output_root_mean_squared_error: 1.2986 - val_loss: 7.2533 - val_y1_output_loss: 1.9326 - val_y2_output_loss: 5.7583 - val_y1_output_root_mean_squared_error: 1.4103 - val_y2_output_root_mean_squared_error: 2.2944
# Epoch 107/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1708 - y1_output_loss: 0.8383 - y2_output_loss: 2.3059 - y1_output_root_mean_squared_error: 0.9199 - y2_output_root_mean_squared_error: 1.5246 - val_loss: 2.7424 - val_y1_output_loss: 0.5226 - val_y2_output_loss: 2.4607 - val_y1_output_root_mean_squared_error: 0.7269 - val_y2_output_root_mean_squared_error: 1.4879
# Epoch 108/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.2950 - y1_output_loss: 0.5492 - y2_output_loss: 1.7266 - y1_output_root_mean_squared_error: 0.7444 - y2_output_root_mean_squared_error: 1.3194 - val_loss: 2.6539 - val_y1_output_loss: 0.6190 - val_y2_output_loss: 2.1985 - val_y1_output_root_mean_squared_error: 0.7973 - val_y2_output_root_mean_squared_error: 1.4206
# Epoch 109/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.4488 - y1_output_loss: 0.6501 - y2_output_loss: 1.7886 - y1_output_root_mean_squared_error: 0.8045 - y2_output_root_mean_squared_error: 1.3422 - val_loss: 3.4764 - val_y1_output_loss: 0.6288 - val_y2_output_loss: 3.2335 - val_y1_output_root_mean_squared_error: 0.7995 - val_y2_output_root_mean_squared_error: 1.6844
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1556 - y1_output_loss: 0.5856 - y2_output_loss: 1.5813 - y1_output_root_mean_squared_error: 0.7669 - y2_output_root_mean_squared_error: 1.2520 - val_loss: 5.3654 - val_y1_output_loss: 1.1630 - val_y2_output_loss: 4.1146 - val_y1_output_root_mean_squared_error: 1.0821 - val_y2_output_root_mean_squared_error: 2.0481
# Epoch 111/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5481 - y1_output_loss: 0.6029 - y2_output_loss: 1.9599 - y1_output_root_mean_squared_error: 0.7591 - y2_output_root_mean_squared_error: 1.4042 - val_loss: 8.4575 - val_y1_output_loss: 3.6764 - val_y2_output_loss: 4.7090 - val_y1_output_root_mean_squared_error: 1.9365 - val_y2_output_root_mean_squared_error: 2.1697
# Epoch 112/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.8707 - y1_output_loss: 0.7554 - y2_output_loss: 2.0941 - y1_output_root_mean_squared_error: 0.8727 - y2_output_root_mean_squared_error: 1.4523 - val_loss: 3.5766 - val_y1_output_loss: 1.0369 - val_y2_output_loss: 2.6442 - val_y1_output_root_mean_squared_error: 1.0190 - val_y2_output_root_mean_squared_error: 1.5932
# Epoch 113/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.7504 - y1_output_loss: 0.4482 - y2_output_loss: 1.2887 - y1_output_root_mean_squared_error: 0.6705 - y2_output_root_mean_squared_error: 1.1405 - val_loss: 2.7795 - val_y1_output_loss: 0.6822 - val_y2_output_loss: 2.1028 - val_y1_output_root_mean_squared_error: 0.8343 - val_y2_output_root_mean_squared_error: 1.4434
# Epoch 114/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.8540 - y1_output_loss: 0.4988 - y2_output_loss: 1.3535 - y1_output_root_mean_squared_error: 0.7012 - y2_output_root_mean_squared_error: 1.1672 - val_loss: 3.9409 - val_y1_output_loss: 1.1197 - val_y2_output_loss: 2.8395 - val_y1_output_root_mean_squared_error: 1.0667 - val_y2_output_root_mean_squared_error: 1.6742
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8411 - y1_output_loss: 0.6690 - y2_output_loss: 2.1662 - y1_output_root_mean_squared_error: 0.8177 - y2_output_root_mean_squared_error: 1.4739 - val_loss: 6.5589 - val_y1_output_loss: 1.9957 - val_y2_output_loss: 4.7523 - val_y1_output_root_mean_squared_error: 1.4376 - val_y2_output_root_mean_squared_error: 2.1195
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.0579 - y1_output_loss: 0.4976 - y2_output_loss: 1.5626 - y1_output_root_mean_squared_error: 0.7011 - y2_output_root_mean_squared_error: 1.2515 - val_loss: 3.5541 - val_y1_output_loss: 0.5644 - val_y2_output_loss: 3.3748 - val_y1_output_root_mean_squared_error: 0.7563 - val_y2_output_root_mean_squared_error: 1.7269
# Epoch 117/500
# 614/614 [==============================] - 0s 135us/sample - loss: 1.9964 - y1_output_loss: 0.4768 - y2_output_loss: 1.5034 - y1_output_root_mean_squared_error: 0.6930 - y2_output_root_mean_squared_error: 1.2313 - val_loss: 2.7236 - val_y1_output_loss: 0.5293 - val_y2_output_loss: 2.2723 - val_y1_output_root_mean_squared_error: 0.7298 - val_y2_output_root_mean_squared_error: 1.4802
# Epoch 118/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.0093 - y1_output_loss: 0.4923 - y2_output_loss: 1.5234 - y1_output_root_mean_squared_error: 0.7025 - y2_output_root_mean_squared_error: 1.2312 - val_loss: 5.6615 - val_y1_output_loss: 0.7711 - val_y2_output_loss: 5.3692 - val_y1_output_root_mean_squared_error: 0.8881 - val_y2_output_root_mean_squared_error: 2.2075
# Epoch 119/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.8089 - y1_output_loss: 0.4708 - y2_output_loss: 1.3393 - y1_output_root_mean_squared_error: 0.6870 - y2_output_root_mean_squared_error: 1.1563 - val_loss: 4.7361 - val_y1_output_loss: 0.9694 - val_y2_output_loss: 4.0704 - val_y1_output_root_mean_squared_error: 1.0003 - val_y2_output_root_mean_squared_error: 1.9328
# Epoch 120/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8338 - y1_output_loss: 0.6978 - y2_output_loss: 2.1267 - y1_output_root_mean_squared_error: 0.8366 - y2_output_root_mean_squared_error: 1.4608 - val_loss: 2.5558 - val_y1_output_loss: 0.5487 - val_y2_output_loss: 2.1134 - val_y1_output_root_mean_squared_error: 0.7387 - val_y2_output_root_mean_squared_error: 1.4178
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4029 - y1_output_loss: 0.1115 - y2_output_loss: 0.2898 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.5401 - val_loss: 1.3842 - val_y1_output_loss: 0.3342 - val_y2_output_loss: 1.0158 - val_y1_output_root_mean_squared_error: 0.5832 - val_y2_output_root_mean_squared_error: 1.0218
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4572 - y1_output_loss: 0.1252 - y2_output_loss: 0.3301 - y1_output_root_mean_squared_error: 0.3548 - y2_output_root_mean_squared_error: 0.5756 - val_loss: 0.9289 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.7211 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.8485
# Epoch 463/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3775 - y1_output_loss: 0.1119 - y2_output_loss: 0.2776 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5152 - val_loss: 3.7421 - val_y1_output_loss: 0.4852 - val_y2_output_loss: 3.2309 - val_y1_output_root_mean_squared_error: 0.6929 - val_y2_output_root_mean_squared_error: 1.8061
# Epoch 464/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4658 - y1_output_loss: 0.1174 - y2_output_loss: 0.3502 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.5914 - val_loss: 1.2515 - val_y1_output_loss: 0.2567 - val_y2_output_loss: 1.0481 - val_y1_output_root_mean_squared_error: 0.5040 - val_y2_output_root_mean_squared_error: 0.9988
# Epoch 465/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3784 - y1_output_loss: 0.1134 - y2_output_loss: 0.2620 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.5139 - val_loss: 0.9316 - val_y1_output_loss: 0.2101 - val_y2_output_loss: 0.7342 - val_y1_output_root_mean_squared_error: 0.4622 - val_y2_output_root_mean_squared_error: 0.8473
# Epoch 466/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3961 - y1_output_loss: 0.1227 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5232 - val_loss: 1.1550 - val_y1_output_loss: 0.3515 - val_y2_output_loss: 0.8365 - val_y1_output_root_mean_squared_error: 0.5957 - val_y2_output_root_mean_squared_error: 0.8945
# Epoch 467/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.5050 - y1_output_loss: 0.1261 - y2_output_loss: 0.3791 - y1_output_root_mean_squared_error: 0.3559 - y2_output_root_mean_squared_error: 0.6151 - val_loss: 1.1422 - val_y1_output_loss: 0.2049 - val_y2_output_loss: 0.9131 - val_y1_output_root_mean_squared_error: 0.4545 - val_y2_output_root_mean_squared_error: 0.9673
# Epoch 468/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5014 - y1_output_loss: 0.1431 - y2_output_loss: 0.3625 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.5989 - val_loss: 0.8456 - val_y1_output_loss: 0.2275 - val_y2_output_loss: 0.6068 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.7851
# Epoch 469/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4187 - y1_output_loss: 0.1398 - y2_output_loss: 0.3460 - y1_output_root_mean_squared_error: 0.3542 - y2_output_root_mean_squared_error: 0.5416 - val_loss: 25.1142 - val_y1_output_loss: 4.0883 - val_y2_output_loss: 21.8433 - val_y1_output_root_mean_squared_error: 2.0224 - val_y2_output_root_mean_squared_error: 4.5852
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.9733 - y1_output_loss: 0.2414 - y2_output_loss: 0.7356 - y1_output_root_mean_squared_error: 0.4894 - y2_output_root_mean_squared_error: 0.8566 - val_loss: 1.2051 - val_y1_output_loss: 0.4069 - val_y2_output_loss: 0.7769 - val_y1_output_root_mean_squared_error: 0.6376 - val_y2_output_root_mean_squared_error: 0.8936
# Epoch 471/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3557 - y1_output_loss: 0.1194 - y2_output_loss: 0.2355 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.4862 - val_loss: 0.8497 - val_y1_output_loss: 0.1739 - val_y2_output_loss: 0.6916 - val_y1_output_root_mean_squared_error: 0.4206 - val_y2_output_root_mean_squared_error: 0.8202
# Epoch 472/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4359 - y1_output_loss: 0.1228 - y2_output_loss: 0.3211 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5601 - val_loss: 2.1056 - val_y1_output_loss: 0.5036 - val_y2_output_loss: 1.5673 - val_y1_output_root_mean_squared_error: 0.7077 - val_y2_output_root_mean_squared_error: 1.2668
# Epoch 473/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5911 - y1_output_loss: 0.1483 - y2_output_loss: 0.4396 - y1_output_root_mean_squared_error: 0.3867 - y2_output_root_mean_squared_error: 0.6645 - val_loss: 0.8350 - val_y1_output_loss: 0.2107 - val_y2_output_loss: 0.6302 - val_y1_output_root_mean_squared_error: 0.4623 - val_y2_output_root_mean_squared_error: 0.7883
# Epoch 474/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4088 - y1_output_loss: 0.1178 - y2_output_loss: 0.2875 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.5385 - val_loss: 0.9796 - val_y1_output_loss: 0.3059 - val_y2_output_loss: 0.6607 - val_y1_output_root_mean_squared_error: 0.5520 - val_y2_output_root_mean_squared_error: 0.8215
# Epoch 475/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4010 - y1_output_loss: 0.1196 - y2_output_loss: 0.2787 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5297 - val_loss: 0.9446 - val_y1_output_loss: 0.2009 - val_y2_output_loss: 0.7650 - val_y1_output_root_mean_squared_error: 0.4484 - val_y2_output_root_mean_squared_error: 0.8623
# Epoch 476/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3876 - y1_output_loss: 0.1263 - y2_output_loss: 0.2588 - y1_output_root_mean_squared_error: 0.3565 - y2_output_root_mean_squared_error: 0.5104 - val_loss: 0.8635 - val_y1_output_loss: 0.1859 - val_y2_output_loss: 0.7035 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.8216
# Epoch 477/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4314 - y1_output_loss: 0.1183 - y2_output_loss: 0.3119 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.5597 - val_loss: 1.0499 - val_y1_output_loss: 0.3164 - val_y2_output_loss: 0.7246 - val_y1_output_root_mean_squared_error: 0.5708 - val_y2_output_root_mean_squared_error: 0.8509
# Epoch 478/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4254 - y1_output_loss: 0.1215 - y2_output_loss: 0.3100 - y1_output_root_mean_squared_error: 0.3478 - y2_output_root_mean_squared_error: 0.5518 - val_loss: 3.1208 - val_y1_output_loss: 0.5286 - val_y2_output_loss: 2.7536 - val_y1_output_root_mean_squared_error: 0.7229 - val_y2_output_root_mean_squared_error: 1.6119
# Epoch 479/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4939 - y1_output_loss: 0.1347 - y2_output_loss: 0.3574 - y1_output_root_mean_squared_error: 0.3669 - y2_output_root_mean_squared_error: 0.5994 - val_loss: 0.8363 - val_y1_output_loss: 0.2410 - val_y2_output_loss: 0.5976 - val_y1_output_root_mean_squared_error: 0.4948 - val_y2_output_root_mean_squared_error: 0.7691
# Epoch 480/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3966 - y1_output_loss: 0.1116 - y2_output_loss: 0.2850 - y1_output_root_mean_squared_error: 0.3349 - y2_output_root_mean_squared_error: 0.5333 - val_loss: 0.8710 - val_y1_output_loss: 0.2386 - val_y2_output_loss: 0.6177 - val_y1_output_root_mean_squared_error: 0.4911 - val_y2_output_root_mean_squared_error: 0.7936
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3653 - y1_output_loss: 0.1150 - y2_output_loss: 0.2492 - y1_output_root_mean_squared_error: 0.3379 - y2_output_root_mean_squared_error: 0.5011 - val_loss: 1.4930 - val_y1_output_loss: 0.5222 - val_y2_output_loss: 0.9414 - val_y1_output_root_mean_squared_error: 0.7263 - val_y2_output_root_mean_squared_error: 0.9826
# Epoch 482/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4627 - y1_output_loss: 0.1335 - y2_output_loss: 0.3282 - y1_output_root_mean_squared_error: 0.3653 - y2_output_root_mean_squared_error: 0.5738 - val_loss: 0.8780 - val_y1_output_loss: 0.2610 - val_y2_output_loss: 0.5994 - val_y1_output_root_mean_squared_error: 0.5168 - val_y2_output_root_mean_squared_error: 0.7816
# Epoch 483/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4550 - y1_output_loss: 0.1178 - y2_output_loss: 0.3338 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5801 - val_loss: 0.7998 - val_y1_output_loss: 0.2195 - val_y2_output_loss: 0.5764 - val_y1_output_root_mean_squared_error: 0.4727 - val_y2_output_root_mean_squared_error: 0.7592
# Epoch 484/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3562 - y1_output_loss: 0.1198 - y2_output_loss: 0.2371 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.4865 - val_loss: 1.2149 - val_y1_output_loss: 0.3715 - val_y2_output_loss: 0.8181 - val_y1_output_root_mean_squared_error: 0.6162 - val_y2_output_root_mean_squared_error: 0.9139
# Epoch 485/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4114 - y1_output_loss: 0.1274 - y2_output_loss: 0.2853 - y1_output_root_mean_squared_error: 0.3570 - y2_output_root_mean_squared_error: 0.5328 - val_loss: 0.8508 - val_y1_output_loss: 0.2501 - val_y2_output_loss: 0.5961 - val_y1_output_root_mean_squared_error: 0.5052 - val_y2_output_root_mean_squared_error: 0.7718
# Epoch 486/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4678 - y1_output_loss: 0.1220 - y2_output_loss: 0.3443 - y1_output_root_mean_squared_error: 0.3499 - y2_output_root_mean_squared_error: 0.5877 - val_loss: 1.4521 - val_y1_output_loss: 0.2917 - val_y2_output_loss: 1.2225 - val_y1_output_root_mean_squared_error: 0.5410 - val_y2_output_root_mean_squared_error: 1.0768
# Epoch 487/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3501 - y1_output_loss: 0.1038 - y2_output_loss: 0.2445 - y1_output_root_mean_squared_error: 0.3221 - y2_output_root_mean_squared_error: 0.4963 - val_loss: 0.7983 - val_y1_output_loss: 0.2155 - val_y2_output_loss: 0.5801 - val_y1_output_root_mean_squared_error: 0.4697 - val_y2_output_root_mean_squared_error: 0.7600
# Epoch 488/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3846 - y1_output_loss: 0.1242 - y2_output_loss: 0.2771 - y1_output_root_mean_squared_error: 0.3403 - y2_output_root_mean_squared_error: 0.5185 - val_loss: 3.4403 - val_y1_output_loss: 1.4733 - val_y2_output_loss: 1.8805 - val_y1_output_root_mean_squared_error: 1.2260 - val_y2_output_root_mean_squared_error: 1.3918
# Epoch 489/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4946 - y1_output_loss: 0.1319 - y2_output_loss: 0.3603 - y1_output_root_mean_squared_error: 0.3631 - y2_output_root_mean_squared_error: 0.6023 - val_loss: 1.0912 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 0.9002 - val_y1_output_root_mean_squared_error: 0.4591 - val_y2_output_root_mean_squared_error: 0.9383
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3572 - y1_output_loss: 0.1080 - y2_output_loss: 0.2610 - y1_output_root_mean_squared_error: 0.3279 - y2_output_root_mean_squared_error: 0.4997 - val_loss: 6.4675 - val_y1_output_loss: 0.4356 - val_y2_output_loss: 6.2047 - val_y1_output_root_mean_squared_error: 0.6643 - val_y2_output_root_mean_squared_error: 2.4548
# Epoch 491/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5447 - y1_output_loss: 0.1387 - y2_output_loss: 0.4031 - y1_output_root_mean_squared_error: 0.3738 - y2_output_root_mean_squared_error: 0.6364 - val_loss: 0.8563 - val_y1_output_loss: 0.2066 - val_y2_output_loss: 0.6388 - val_y1_output_root_mean_squared_error: 0.4582 - val_y2_output_root_mean_squared_error: 0.8040
# Epoch 492/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4109 - y1_output_loss: 0.1111 - y2_output_loss: 0.2981 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.5472 - val_loss: 0.8267 - val_y1_output_loss: 0.2115 - val_y2_output_loss: 0.6062 - val_y1_output_root_mean_squared_error: 0.4608 - val_y2_output_root_mean_squared_error: 0.7838
# Epoch 493/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3649 - y1_output_loss: 0.0995 - y2_output_loss: 0.2694 - y1_output_root_mean_squared_error: 0.3168 - y2_output_root_mean_squared_error: 0.5144 - val_loss: 1.0505 - val_y1_output_loss: 0.2490 - val_y2_output_loss: 0.7949 - val_y1_output_root_mean_squared_error: 0.5054 - val_y2_output_root_mean_squared_error: 0.8917
# Epoch 494/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3750 - y1_output_loss: 0.1123 - y2_output_loss: 0.2613 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.5115 - val_loss: 0.7457 - val_y1_output_loss: 0.1887 - val_y2_output_loss: 0.5512 - val_y1_output_root_mean_squared_error: 0.4336 - val_y2_output_root_mean_squared_error: 0.7468
# Epoch 495/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3276 - y1_output_loss: 0.1084 - y2_output_loss: 0.2166 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.4674 - val_loss: 0.7594 - val_y1_output_loss: 0.1938 - val_y2_output_loss: 0.5572 - val_y1_output_root_mean_squared_error: 0.4441 - val_y2_output_root_mean_squared_error: 0.7497
# Epoch 496/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2999 - y1_output_loss: 0.1031 - y2_output_loss: 0.1966 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.4445 - val_loss: 1.5029 - val_y1_output_loss: 0.6375 - val_y2_output_loss: 0.8440 - val_y1_output_root_mean_squared_error: 0.8025 - val_y2_output_root_mean_squared_error: 0.9268
# Epoch 497/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4085 - y1_output_loss: 0.1416 - y2_output_loss: 0.2661 - y1_output_root_mean_squared_error: 0.3759 - y2_output_root_mean_squared_error: 0.5168 - val_loss: 0.8511 - val_y1_output_loss: 0.2220 - val_y2_output_loss: 0.6196 - val_y1_output_root_mean_squared_error: 0.4731 - val_y2_output_root_mean_squared_error: 0.7920
# Epoch 498/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3709 - y1_output_loss: 0.1081 - y2_output_loss: 0.2601 - y1_output_root_mean_squared_error: 0.3300 - y2_output_root_mean_squared_error: 0.5119 - val_loss: 0.9299 - val_y1_output_loss: 0.2181 - val_y2_output_loss: 0.6975 - val_y1_output_root_mean_squared_error: 0.4707 - val_y2_output_root_mean_squared_error: 0.8416
# Epoch 499/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2983 - y1_output_loss: 0.0944 - y2_output_loss: 0.2060 - y1_output_root_mean_squared_error: 0.3073 - y2_output_root_mean_squared_error: 0.4515 - val_loss: 0.8380 - val_y1_output_loss: 0.1710 - val_y2_output_loss: 0.6491 - val_y1_output_root_mean_squared_error: 0.4172 - val_y2_output_root_mean_squared_error: 0.8149
# Epoch 500/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4274 - y1_output_loss: 0.1206 - y2_output_loss: 0.3078 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5536 - val_loss: 1.0554 - val_y1_output_loss: 0.2897 - val_y2_output_loss: 0.7725 - val_y1_output_root_mean_squared_error: 0.5444 - val_y2_output_root_mean_squared_error: 0.8712

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 1.0554 - y1_output_loss: 0.2963 - y2_output_loss: 0.7598 - y1_output_root_mean_squared_error: 0.5444 - y2_output_root_mean_squared_error: 0.8712
# Loss = 1.0554256206983095, Y1_loss = 0.2963329255580902, Y1_mse = 0.5444431304931641, Y2_loss = 0.7598431706428528, Y2_mse = 0.8712102770805359

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
